# %% [markdown]
# <a href="https://colab.research.google.com/github/anushkaSri-04/mlOpsProject/blob/main/mlOps.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/anushkaSri-04/mlOpsProject
# Out:
# Cloning into 'mlOpsProject'...
# remote: Enumerating objects: 25, done.
# remote: Counting objects: 100% (25/25), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 25 (delta 4), reused 25 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (25/25), done.
# Resolving deltas: 100% (4/4), done.
